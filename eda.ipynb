# %% [markdown]
# # EDA
# Exploring various fingerprint datasets...

# %%
import glob
import matplotlib.pyplot
import os.path
import random
import cv2

datasets_path = os.path.abspath("./datasets/")

# %%
def show_random_images(image_paths):
    shown_image_paths = random.sample(image_paths, 20)

    figure, axes = matplotlib.pyplot.subplots(nrows=2, ncols=4, figsize=(12, 6))

    for i, axis in enumerate(axes.flat):
        image = matplotlib.pyplot.imread(shown_image_paths[i])
        axis.imshow(image, 'gray')
        axis.set_title(os.path.basename(shown_image_paths[i]))

    matplotlib.pyplot.tight_layout(True)
    matplotlib.pyplot.show()

# %% [markdown]
# ## SOCOFing Dataset

# %%
real_images_glob = os.path.join(datasets_path, "SOCOFing/Real/*.BMP")
real_image_paths = glob.glob(real_images_glob)

# %%
real_img = cv2.imread(real_image_paths[0], 0)
print(f'Size: {len(real_image_paths)}, shape: {real_img.shape}')
# Out:
# Size: 6000, shape: (103, 96)

# %%
show_random_images(real_image_paths)

# %%
altered_images_glob = os.path.join(datasets_path, "SOCOFing/Altered/Altered-Easy/*.BMP")
altered_image_paths = glob.glob(altered_images_glob)

# %%
alterned_img = cv2.imread(altered_image_paths[0], 0)
print(f'Size: {len(altered_image_paths)}, shape: {alterned_img.shape}')
# Out:
# Size: 17931, shape: (103, 96)

# %%
# todo: figure out the weird colors
# L.S: By default, matplotlib use a colormap which maps intensities to colors. https://matplotlib.org/3.1.0/tutorials/colors/colormaps.html
show_random_images(altered_image_paths)

# %% [markdown]
# ## NIST SD04

# %%
images_glob = os.path.join(datasets_path, "NISTsd04/png_txt/*/*.png")
image_paths = glob.glob(images_glob)

# %%
first_img = cv2.imread(image_paths[0], 0)
print(f'Size: {len(image_paths)}, shape: {first_img.shape}')
# Out:
# Size: 4000, shape: (512, 512)

# %%
# todo: figure out the weird colors
show_random_images(image_paths)

# %% [markdown]
# ## CASIAv5

# %%
images_glob = os.path.join(datasets_path, "CASIAv5/*/*/*.bmp")
image_paths = glob.glob(images_glob)

# %%
first_img = cv2.imread(image_paths[0], 0)
print(f'Size: {len(image_paths)}, shape: {first_img.shape}')
# Out:
# Size: 20000, shape: (356, 328)

# %%
show_random_images(image_paths)

# %% [markdown]
# ## Hong Kong PolyU

# %% [markdown]
# ### Contact-Based

# %%
images_glob = os.path.join(datasets_path, "PolyU/contact-based_fingerprints/*/*.jpg")
image_paths = glob.glob(images_glob)

# %%
first_img = cv2.imread(image_paths[0], 0)
print(f'Size: {len(image_paths)}, shape: {first_img.shape}')
# Out:
# Size: 2976, shape: (356, 328)

# %%
show_random_images(image_paths)

# %% [markdown]
# ### Contactless

# %%
images_glob = os.path.join(datasets_path, "PolyU/contactless_2d_fingerprint_images/*/*/*.bmp")
image_paths = glob.glob(images_glob)

# %%
first_img = cv2.imread(image_paths[0], 0)
print(f'Size: {len(image_paths)}, shape: {first_img.shape}')
# Out:
# Size: 2976, shape: (900, 1400)

# %%
show_random_images(image_paths)

# %% [markdown]
# ### Contactless Processed

# %%
images_glob = os.path.join(datasets_path, "PolyU/processed_contactless_2d_fingerprint_images/*/*/*.bmp")
image_paths = glob.glob(images_glob)

# %%
first_img = cv2.imread(image_paths[0], 0)
print(f'Size: {len(image_paths)}, shape: {first_img.shape}')
# Out:
# Size: 2976, shape: (225, 350)

# %%
show_random_images(image_paths)
